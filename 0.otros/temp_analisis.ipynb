# %%
import pandas as pd
from ast import literal_eval

df=pd.read_excel("resultados/resultados_entrenamiento_grid_search.xlsx")
df['sensitivity_per_class']=[literal_eval(i) for i in df['sensitivity_per_class']]
df['specificity_per_class']=[literal_eval(i) for i in df['specificity_per_class']]
df['precision_per_class']=[literal_eval(i) for i in df['precision_per_class']]
df['recall_per_class']=[literal_eval(i) for i in df['recall_per_class']]
df['best_params']=[literal_eval(i) for i in df['best_params']]

df=df[['model', 'encoding', 'accuracy', 'f1_score_weighted',
                                                         'f1_score_macro', 'precision_weighted', 'precision_macro',
                                                         'sensitivity_per_class', 'specificity_per_class', 'precision_per_class',
                                                         'recall_per_class', 'best_params', 'cv_score', 'model_name']]
df.head()
# Out:
#            model    encoding  accuracy  f1_score_weighted  f1_score_macro  \
# 0            SVM  AS-One Hot  0.996183           0.996183        0.995831
# 1  Random Forest  AS-One Hot  0.995229           0.995231        0.995218
# 2        XGBoost  AS-One Hot  0.995229           0.995229        0.994756
# 3            SVM   AS-K-mers  0.996183           0.996183        0.995831
# 4  Random Forest   AS-K-mers  0.995229           0.995233        0.995122
#
#    precision_weighted  precision_macro  \
# 0            0.996300         0.995934
# 1            0.995385         0.995792
# 2            0.995345         0.994859
# 3            0.996300         0.995934
# 4            0.995361         0.995572
#
#                                sensitivity_per_class  \
# 0  {'Flavobacterium': 1.0, 'Vibrio': 1.0, 'Coryne...
# 1  {'Flavobacterium': 1.0, 'Vibrio': 1.0, 'Coryne...
# 2  {'Flavobacterium': 1.0, 'Vibrio': 1.0, 'Coryne...
# 3  {'Flavobacterium': 1.0, 'Vibrio': 1.0, 'Coryne...
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Crear la cadena de conexión
DATABASE_URL = "postgresql://daso:cleo1234@localhost:5432/postgres"

# Crear el engine de SQLAlchemy
engine = create_engine(DATABASE_URL)

# Opcional: probar la conexión
try:
    connection = engine.connect()
    print("Conexión exitosa")
    connection.close()
except Exception as e:
    print(f"Error de conexión: {e}")
# Out:
# Conexión exitosa
